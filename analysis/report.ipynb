# %% [markdown]
# ### Report on the patterns that I have noticed.

# %% [markdown]
# We need to maintain a balance between weight decay, data split, learning rate, sequence length, and other factors.
#
# If we have more data in the training set, the model is more likely to learn effectively rather than overfit.
#
# If we increase the modulus, there will be more unique pairs, though not necessarily more sequences.
#
# If the validation loss graph is sloping upward, it may increase significantly before coming back down, and this pattern can repeat.
#
# If the validation loss trends downward, it will eventually converge to a finite value.
#
# When the modulus is large, the loss tends to decrease more slowly.

# %% [markdown]
# ## Generalization after short overfitting.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

sys.path.insert(0, str(PROJECT_ROOT))

from utils.explained_variance_ratio import plot_checkpoints



plot_checkpoints(['sus_1.pth', 'sus_2.pth', 'sus_3.pth'])

# %% [markdown]
# ## Generalization after long overfitting.

# %%
plot_checkpoints(['sus_6.pth', 'sus_7.pth'])

# %%
plot_checkpoints(['sus_4.pth'])

# %% [markdown]
# Now we only taining the model on binary opreation.
# Let's see if the accuracy in validation goes to zero for long time.

# %%
plot_checkpoints(['sus_8.pth', 'sus_8_1000_batch.pth'])
